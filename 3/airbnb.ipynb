# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
q4 = pd.read_csv('/content/drive/MyDrive/dataset/airbnb/listings_q4.csv')
q3 = pd.read_csv('/content/drive/MyDrive/dataset/airbnb/listings_q3.csv')
q2 = pd.read_csv('/content/drive/MyDrive/dataset/airbnb/listings_q2.csv')

# %%
q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3672 entries, 0 to 3671
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3672 non-null   int64
#  1   name                            3672 non-null   object
#  2   host_id                         3672 non-null   int64
#  3   host_name                       3661 non-null   object
#  4   neighbourhood_group             3672 non-null   object
#  5   neighbourhood                   3672 non-null   object
#  6   latitude                        3672 non-null   float64
#  7   longitude                       3672 non-null   float64
#  8   room_type                       3672 non-null   object
#  9   price                           3672 non-null   int64
#  10  minimum_nights                  3672 non-null   int64
#  11  number_of_reviews               3672 non-null   int64
# ...

# %%
q4.drop(columns = ['number_of_reviews_ltm',
         'license'],inplace = True)
q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3672 entries, 0 to 3671
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3672 non-null   int64
#  1   name                            3672 non-null   object
#  2   host_id                         3672 non-null   int64
#  3   host_name                       3661 non-null   object
#  4   neighbourhood_group             3672 non-null   object
#  5   neighbourhood                   3672 non-null   object
#  6   latitude                        3672 non-null   float64
#  7   longitude                       3672 non-null   float64
#  8   room_type                       3672 non-null   object
#  9   price                           3672 non-null   int64
#  10  minimum_nights                  3672 non-null   int64
#  11  number_of_reviews               3672 non-null   int64
# ...

# %%
q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4221 entries, 0 to 4220
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4221 non-null   int64
#  1   name                            4221 non-null   object
#  2   host_id                         4221 non-null   int64
#  3   host_name                       4213 non-null   object
#  4   neighbourhood_group             4221 non-null   object
#  5   neighbourhood                   4221 non-null   object
#  6   latitude                        4221 non-null   float64
#  7   longitude                       4221 non-null   float64
#  8   room_type                       4221 non-null   object
#  9   price                           4221 non-null   int64
#  10  minimum_nights                  4221 non-null   int64
#  11  number_of_reviews               4221 non-null   int64
# ...

# %%
q3.drop(columns = ['number_of_reviews_ltm',
         'license'], inplace = True)
q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4221 entries, 0 to 4220
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4221 non-null   int64
#  1   name                            4221 non-null   object
#  2   host_id                         4221 non-null   int64
#  3   host_name                       4213 non-null   object
#  4   neighbourhood_group             4221 non-null   object
#  5   neighbourhood                   4221 non-null   object
#  6   latitude                        4221 non-null   float64
#  7   longitude                       4221 non-null   float64
#  8   room_type                       4221 non-null   object
#  9   price                           4221 non-null   int64
#  10  minimum_nights                  4221 non-null   int64
#  11  number_of_reviews               4221 non-null   int64
# ...

# %%
q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4238 non-null   int64
#  1   name                            4238 non-null   object
#  2   host_id                         4238 non-null   int64
#  3   host_name                       4230 non-null   object
#  4   neighbourhood_group             4238 non-null   object
#  5   neighbourhood                   4238 non-null   object
#  6   latitude                        4238 non-null   float64
#  7   longitude                       4238 non-null   float64
#  8   room_type                       4238 non-null   object
#  9   price                           4238 non-null   int64
#  10  minimum_nights                  4238 non-null   int64
#  11  number_of_reviews               4238 non-null   int64
# ...

# %%
q2_3=q2.append(q3, ignore_index=True)
df = q2_3.append(q4, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12131 entries, 0 to 12130
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              12131 non-null  int64
#  1   name                            12131 non-null  object
#  2   host_id                         12131 non-null  int64
#  3   host_name                       12104 non-null  object
#  4   neighbourhood_group             12131 non-null  object
#  5   neighbourhood                   12131 non-null  object
#  6   latitude                        12131 non-null  float64
#  7   longitude                       12131 non-null  float64
#  8   room_type                       12131 non-null  object
#  9   price                           12131 non-null  int64
#  10  minimum_nights                  12131 non-null  int64
#  11  number_of_reviews               12131 non-null  int64
# ...

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44129  103.79571  Private room     81
# 1      Central Region   Bukit Timah   1.33432  103.78521  Private room     80
# 2        North Region     Woodlands   1.44041  103.79669  Private room     67
# 3         East Region      Tampines   1.34537  103.95887  Private room    177
# 4         East Region      Tampines   1.34754  103.95958  Private room     81
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df.drop(columns=['name',
                 'last_review',
                 'reviews_per_month'], inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12131 entries, 0 to 12130
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              12131 non-null  int64
#  1   host_id                         12131 non-null  int64
#  2   host_name                       12104 non-null  object
#  3   neighbourhood_group             12131 non-null  object
#  4   neighbourhood                   12131 non-null  object
#  5   latitude                        12131 non-null  float64
#  6   longitude                       12131 non-null  float64
#  7   room_type                       12131 non-null  object
#  8   price                           12131 non-null  int64
#  9   minimum_nights                  12131 non-null  int64
#  10  number_of_reviews               12131 non-null  int64
#  11  calculated_host_listings_count  12131 non-null  int64
# ...

# %%
df.nunique()
# Out:
# id                                4942
# host_id                           1294
# host_name                          990
# neighbourhood_group                  5
# neighbourhood                       44
# latitude                          3513
# longitude                         3758
# room_type                            4
# price                              646
# minimum_nights                      78
# number_of_reviews                  214
# calculated_host_listings_count      66
# availability_365                   362
# dtype: int64

# %%
df.sort_values('id')
# Out:
#              id    host_id     host_name neighbourhood_group  neighbourhood  \
# 0         49091     266763     Francesca        North Region      Woodlands
# 1         50646     227796       Sujatha      Central Region    Bukit Timah
# 8459      50646     227796       Sujatha      Central Region    Bukit Timah
# 4238      50646     227796       Sujatha      Central Region    Bukit Timah
# 2         56334     266763     Francesca        North Region      Woodlands
# ...         ...        ...           ...                 ...            ...
# 12126  53905492  434862321  New Cape Inn      Central Region    Bukit Merah
# 12127  53905653  434862321  New Cape Inn      Central Region    Bukit Merah
# 12128  53910005  124297243       Beverly      Central Region  Marine Parade
# 12129  53910434  156409670           Tia      Central Region        Kallang
# 12130  53927825  432072313  Holidayhomes         East Region          Bedok
#
# ...

# %%
df2= df.drop_duplicates(subset=["id"], keep='first')

df2
# Out:
#              id    host_id     host_name neighbourhood_group  neighbourhood  \
# 0         49091     266763     Francesca        North Region      Woodlands
# 1         50646     227796       Sujatha      Central Region    Bukit Timah
# 2         56334     266763     Francesca        North Region      Woodlands
# 3         71609     367042       Belinda         East Region       Tampines
# 4         71896     367042       Belinda         East Region       Tampines
# ...         ...        ...           ...                 ...            ...
# 12126  53905492  434862321  New Cape Inn      Central Region    Bukit Merah
# 12127  53905653  434862321  New Cape Inn      Central Region    Bukit Merah
# 12128  53910005  124297243       Beverly      Central Region  Marine Parade
# 12129  53910434  156409670           Tia      Central Region        Kallang
# 12130  53927825  432072313  Holidayhomes         East Region          Bedok
#
# ...

# %%
#excluded minimum night > 365 days
df2.sort_values('minimum_nights')
df1 = df2.loc[df2["minimum_nights"] <=365 ]

# %%
df1.sort_values('minimum_nights')
# Out:
#             id    host_id             host_name neighbourhood_group  \
# 2472  36888718   20883050                 Alvin      Central Region
# 2042  31960810  218722083             Ann Siang      Central Region
# 2041  31960343  218722083             Ann Siang      Central Region
# 2040  31959810  218722083             Ann Siang      Central Region
# 2034  31812483  218722083             Ann Siang      Central Region
# ...        ...        ...                   ...                 ...
# 679   13965663   46515276                   Ark      Central Region
# 286    6837947   35833085              Benedict   North-East Region
# 189    5319766   27516195                Leanne      Central Region
# 409    8890247   46515276                   Ark      Central Region
# 1621  24950322  178584113  Oakwood Premier AMTD      Central Region
#
#       neighbourhood  latitude  longitude        room_type  price  \
# 2472        Geylang   1.30955  103.88284     Private room     74
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4934 entries, 0 to 12130
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4934 non-null   int64
#  1   host_id                         4934 non-null   int64
#  2   host_name                       4926 non-null   object
#  3   neighbourhood_group             4934 non-null   object
#  4   neighbourhood                   4934 non-null   object
#  5   latitude                        4934 non-null   float64
#  6   longitude                       4934 non-null   float64
#  7   room_type                       4934 non-null   object
#  8   price                           4934 non-null   int64
#  9   minimum_nights                  4934 non-null   int64
#  10  number_of_reviews               4934 non-null   int64
#  11  calculated_host_listings_count  4934 non-null   int64
# ...

# %%
path1 = '/content/drive/MyDrive/dataset/airbnb/'

with open(path1+'df.csv', 'w', encoding = 'utf-8-sig') as f:
  df1.to_csv(f, index=False)
